# %%
import pandas as pd

# %%
imdb_data = pd.read_csv('IMDB-Movie-Data.csv')

# %%
imdb_data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
type(imdb_data) # confirm the data type
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Question 1: How many films were produced in 2015?

# %%
imdb_data.dropna(how='any', inplace=True) # Clean the dataset by removing null values

# %%
imdb_data
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
imdb_data[imdb_data["Year"] == 2015]["Year"].count() # Get all movies produced in 2015 and value count
# Out:
# 50     2015
# 63     2015
# 67     2015
# 84     2015
# 85     2015
#        ...
# 923    2015
# 927    2015
# 950    2015
# 961    2015
# 984    2015
# Name: Year, Length: 109, dtype: int64

# %% [markdown]
# # The total number of movies produced in 2015 is 109

# %% [markdown]
# # How many action movies were produced in 2016?

# %%
new = imdb_data[(imdb_data["Year"] == 2016) & (imdb_data["Genre"].str.contains("Action"))]

# %%
new[["Title","Genre", "Year"]]
# Out:
#                   Title                       Genre  Year
# 4         Suicide Squad    Action,Adventure,Fantasy  2016
# 5        The Great Wall    Action,Adventure,Fantasy  2016
# 8    The Lost City of Z  Action,Adventure,Biography  2016
# 12            Rogue One     Action,Adventure,Sci-Fi  2016
# 14             Colossal         Action,Comedy,Drama  2016
# ..                  ...                         ...   ...
# 615        Bastille Day          Action,Crime,Drama  2016
# 679  The Age of Shadows       Action,Drama,Thriller  2016
# 741      Hands of Stone      Action,Biography,Drama  2016
# 787           Max Steel     Action,Adventure,Family  2016
# 880         Shin Gojira      Action,Adventure,Drama  2016
#
# [62 rows x 3 columns]

# %% [markdown]
# ## Which Director's movies made the most revenue in the dataset?

# %%
revenue_by_director = imdb_data.groupby('Director')[['Revenue (Millions)']].sum()

# %%
revenue_by_director.sort_values(by="Revenue (Millions)", ascending=False)
# Out:
#                    Revenue (Millions)
# Director
# J.J. Abrams                   1683.45
# David Yates                   1630.51
# Christopher Nolan             1515.09
# Michael Bay                   1421.32
# Francis Lawrence              1299.81
# ...                               ...
# Gus Van Sant                     0.02
# Robin Swicord                    0.01
# So Yong Kim                      0.01
# Patricia Rozema                  0.01
# Andy Goddard                     0.00
#
# [524 rows x 1 columns]

# %% [markdown]
# ## J.J Abrams Films made the most revenue
